# %%
import wx
import re
import pickle
import pandas as pd
import sklearn
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.stem import WordNetLemmatizer
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow import keras
kemodel = keras.models.load_model('D:/123/')
nltk.download('wordnet')
nltk.download('omw-1.4')
import neattext.functions as nfx
import matplotlib.pyplot as plt
import plotly.express as plx
import keras
from keras.layers import Embedding,Dense,LSTM,Bidirectional,GlobalMaxPooling1D,Input,Dropout
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from tqdm import tqdm
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

#if app crashes, use del app
del app

## Establishing Dictionary

## Defining dictionary containing all emojis with their meanings.
emojis = {':)': 'smile', ':-)': 'smile', ';d': 'wink', ':-E': 'vampire', ':(': 'sad', 
          ':-(': 'sad', ':-<': 'sad', ':P': 'raspberry', ':O': 'surprised',
          ':-@': 'shocked', ':@': 'shocked',':-$': 'confused', ':\\': 'annoyed', 
          ':#': 'mute', ':X': 'mute', ':^)': 'smile', ':-&': 'confused', '$_$': 'greedy',
          '@@': 'eyeroll', ':-!': 'confused', ':-D': 'smile', ':-0': 'yell', 'O.o': 'confused',
          '<(-_-)>': 'robot', 'd[-_-]b': 'dj', ":'-)": 'sadsmile', ';)': 'wink', 
          ';-)': 'wink', 'O:-)': 'angel','O*-)': 'angel','(:-D': 'gossip', '=^.^=': 'cat'}

## Defining set containing all stopwords in english.
stopwordlist = ['a', 'about', 'above', 'after', 'again', 'ain', 'all', 'am', 'an',
             'and','any','are', 'as', 'at', 'be', 'because', 'been', 'before',
             'being', 'below', 'between','both', 'by', 'can', 'd', 'did', 'do',
             'does', 'doing', 'down', 'during', 'each','few', 'for', 'from', 
             'further', 'had', 'has', 'have', 'having', 'he', 'her', 'here',
             'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in',
             'into','is', 'it', 'its', 'itself', 'just', 'll', 'm', 'ma',
             'me', 'more', 'most','my', 'myself', 'now', 'o', 'of', 'on', 'once',
             'only', 'or', 'other', 'our', 'ours','ourselves', 'out', 'own', 're',
             's', 'same', 'she', "shes", 'should', "shouldve",'so', 'some', 'such',
             't', 'than', 'that', "thatll", 'the', 'their', 'theirs', 'them',
              'through', 'to', 'too','under', 'until', 'up', 've', 'very', 'was',
             'we', 'were', 'what', 'when', 'where','which','while', 'who', 'whom',
             'why', 'will', 'with', 'won', 'y', 'you', "youd","youll", "youre",
             "youve", 'your', 'yours', 'yourself', 'yourselves']

#load vectoriser for text processing
def load_models():

    # Load the vectoriser.
    file = open('./pickle/vectoriser.pickle', 'rb')
    vectoriser = pickle.load(file)
    file.close()
    # Load the LR Model.
    file = open('./pickle/BNB.pickle', 'rb')
    BNBmodel = pickle.load(file)
    file.close()

    file = open('./pickle/Suicide-BNB.pickle', 'rb')
    suicidemodel = pickle.load(file)
    file.close()

    file = open('./pickle/vectoriser-ngram12-suicide.pickle', 'rb')
    vectorisersui = pickle.load(file)
    file.close() 

    return vectoriser, BNBmodel, suicidemodel, vectorisersui

#sentiment prediction model loading
def predict(vectoriser, model, text):
    # Predict the sentiment
    textdata = vectoriser.transform(preprocess(text))
    sentiment = model.predict(textdata)
    
    # Make a list of text with sentiment.
    data = []
    for text, pred in zip(text, sentiment):
        data.append((text,pred))
        
    # Convert the list into a Pandas DataFrame.
    df = pd.DataFrame(data, columns = ['text','sentiment'])
    df = df.replace([0,1], ["Negative","Positive"])
    return df

def predict2(vectoriser, model, text):
    # Predict the sentiment
    textdata = vectoriser.transform(preprocess(text))
    category = model.predict(textdata)
    
    # Make a list of text with sentiment.
    data = []
    for text, pred in zip(text, category):
        data.append((text,pred))
        
    # Convert the list into a Pandas DataFrame.
    df1 = pd.DataFrame(data, columns = ['text','category'])
    df1 = df1.replace([0,1], ["Negative","Positive"])
    return df1

def clean_text(text):
    text_length=[]
    cleaned_text=[]
    for sent in tqdm(text):
        sent=sent.lower()
        sent=nfx.remove_special_characters(sent)
        sent=nfx.remove_stopwords(sent)
#         sent=nfx.remove_shortwords(sent)
        text_length.append(len(sent.split()))
        cleaned_text.append(sent)
    return cleaned_text,text_length
    
#preprocess text input
def preprocess(textdata):
    processedText = []
    
    # Create Lemmatizer and Stemmer.
    wordLemm = WordNetLemmatizer()
    
    # Defining regex patterns.
    urlPattern        = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern       = '@[^\s]+'
    alphaPattern      = "[^a-zA-Z0-9]"
    sequencePattern   = r"(.)\1\1+"
    seqReplacePattern = r"\1\1"
    
    for tweet in textdata:
        tweet = tweet.lower()
        
        # Replace all URls with 'URL'
        tweet = re.sub(urlPattern,' URL',tweet)
        # Replace all emojis.
        for emoji in emojis.keys():
            tweet = tweet.replace(emoji, "EMOJI" + emojis[emoji])        

                    # Replace @USERNAME to 'USER'.
        tweet = re.sub(userPattern,' USER', tweet)        
        # Replace all non alphabets.
        tweet = re.sub(alphaPattern, " ", tweet)
        # Replace 3 or more consecutive letters by 2 letter.
        tweet = re.sub(sequencePattern, seqReplacePattern, tweet)

        tweetwords = ''
        for word in tweet.split():
            # Checking if the word is a stopword.
            #if word not in stopwordlist:
            if len(word)>1:
                # Lemmatizing the word.
                word = wordLemm.lemmatize(word)
                tweetwords += (word+' ')
            
        processedText.append(tweetwords)
        
    return processedText

class MyFrame(wx.Frame):    
    def __init__(self):
        super().__init__(parent=None, title='Sentiment Analysis')
        panel = wx.Panel(self)        
        my_sizer = wx.BoxSizer(wx.VERTICAL)        
        self.text_ctrl = wx.TextCtrl(panel)
        my_sizer.Add(self.text_ctrl, 0, wx.ALL | wx.EXPAND, 5)        
        my_btn = wx.Button(panel, label='Submit the Post')
        my_btn.Bind(wx.EVT_BUTTON, self.on_press)
        my_sizer.Add(my_btn, 0, wx.ALL | wx.CENTER, 5)  
        self.text_ctrl1 = wx.TextCtrl(panel)
        my_sizer.Add(self.text_ctrl1, 0, wx.ALL | wx.EXPAND, 5)                 
        panel.SetSizer(my_sizer)        
        self.Show()

    def on_press(self, event):
        value = self.text_ctrl.GetValue()
        if not value:
            print("Try harder by entering something!")
        else:
            vectoriser, BNBmodel, suicidemodel, vectorisersui = load_models()
            text = [value]
            df = predict(vectoriser, BNBmodel, text)
            if df.sentiment.to_string() =='0    Negative':
                cleaned_train_text,train_text_length=clean_text(text)
                tokenizer=Tokenizer()
                tokenizer.fit_on_texts(cleaned_train_text)
                train_text_seq=tokenizer.texts_to_sequences(cleaned_train_text)
                train_text_pad=pad_sequences(train_text_seq,maxlen=50)
                test_text_seq=tokenizer.texts_to_sequences(cleaned_train_text)
                test_text_pad=pad_sequences(test_text_seq,maxlen=50)
                ##lbl_target=LabelEncoder()
                ##train_output=lbl_target.fit_transform(train_data['class'])
                ##test_output=lbl_target.transform(test_data['class'])
                df1 = kemodel.predict(test_text_pad)
                print(df1.shape)
                ##df1 = predict2(vectorisersui, suicidemodel, text)
                ##print(df1.category)
            else:
                self.text_ctrl1.SetValue(df.sentiment.to_string()) 
                print(df.sentiment)
            ##print(df.head())
            ##print(f'You typed: "{value}"')

if __name__ == '__main__':
    app = wx.App()
    frame = MyFrame()
    app.MainLoop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 16
#      14 from tensorflow import keras
#      15 from tensorflow import keras
# ---> 16 kemodel = keras.models.load_model('D:/123/')
#      17 nltk.download('wordnet')
#      18 nltk.download('omw-1.4')
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\save.py:231, in load_model(filepath, custom_objects, compile, options)
#     226     raise IOError(
#     227         f"No file or directory found at {filepath_str}"
#     228     )
#     230 if tf.io.gfile.isdir(filepath_str):
# --> 231     return saved_model_load.load(
#     232         filepath_str, compile, options
#     233     )
#     234 else:
#     235     if h5py is None:
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\saved_model\load.py:146, in load(path, compile, options)
#     141     loaded = tf.__internal__.saved_model.load_partial(
#     142         path, nodes_to_load, options=options
#     143     )
#     145 # Finalize the loaded layers and remove the extra tracked dependencies.
# --> 146 keras_loader.finalize_objects()
#     147 keras_loader.del_tracking()
#     149 model = loaded["root"]
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\saved_model\load.py:730, in KerasObjectLoader.finalize_objects(self)
#     726 _finalize_config_layers(layers_revived_from_config)
#     728 # Initialize graph networks, now that layer dependencies have been
#     729 # resolved.
# --> 730 self._reconstruct_all_models()
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\saved_model\load.py:749, in KerasObjectLoader._reconstruct_all_models(self)
#     747     all_initialized_models.add(model_id)
#     748     model, layers = self.model_layer_dependencies[model_id]
# --> 749     self._reconstruct_model(model_id, model, layers)
#     750     _finalize_config_layers([model])
#     752 if all_initialized_models != set(self.model_layer_dependencies.keys()):
#     753     # This should not happen.
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\saving\saved_model\load.py:799, in KerasObjectLoader._reconstruct_model(self, model_id, model, layers)
#     787         batch_input_shape = config["layers"][0]["config"][
#     788             "batch_input_shape"
#     789         ]
#     790         layers.insert(
#     791             0,
#     792             input_layer.InputLayer(
#    (...)
#     797             ),
#     798         )
# --> 799 model.__init__(layers, name=config["name"])
#     800 if not model.inputs:
#     801     first_layer = self._get_child_layer_node_ids(model_id)[0]
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\sequential.py:140, in Sequential.__init__(self, layers, name)
#     138     layers = [layers]
#     139 for layer in layers:
# --> 140     self.add(layer)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\sequential.py:234, in Sequential.add(self, layer)
#     229         self._has_explicit_input_shape = True
#     231 elif self.outputs:
#     232     # If the model is being built continuously on top of an input layer:
#     233     # refresh its output.
# --> 234     output_tensor = layer(self.outputs[0])
#     235     if len(tf.nest.flatten(output_tensor)) != 1:
#     236         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\base_rnn.py:553, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     548 inputs, initial_state, constants = rnn_utils.standardize_args(
#     549     inputs, initial_state, constants, self._num_constants
#     550 )
#     552 if initial_state is None and constants is None:
# --> 553     return super().__call__(inputs, **kwargs)
#     555 # If any of `initial_state` or `constants` are specified and are Keras
#     556 # tensors, then add them to the inputs and temporarily modify the
#     557 # input_spec to include them.
#     559 additional_inputs = []
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:1011, in Layer.__call__(self, *args, **kwargs)
#    1003 # Functional Model construction mode is invoked when `Layer`s are called
#    1004 # on symbolic `KerasTensor`s, i.e.:
#    1005 # >> inputs = tf.keras.Input(10)
#    1006 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1007 # >> model = tf.keras.Model(inputs, outputs)
#    1008 if _in_functional_construction_mode(
#    1009     self, inputs, args, kwargs, input_list
#    1010 ):
# -> 1011     return self._functional_construction_call(
#    1012         inputs, args, kwargs, input_list
#    1013     )
#    1015 # Maintains info about the `Layer.call` stack.
#    1016 call_context = base_layer_utils.call_context()
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:2498, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2491         training_arg_passed_by_framework = True
#    2493 with call_context.enter(
#    2494     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2495 ):
#    2496     # Check input assumptions set after layer building, e.g. input
#    2497     # shape.
# -> 2498     outputs = self._keras_tensor_symbolic_call(
#    2499         inputs, input_masks, args, kwargs
#    2500     )
#    2502     if outputs is None:
#    2503         raise ValueError(
#    2504             "A layer's `call` method should return a "
#    2505             "Tensor or a list of Tensors, not None "
#    2506             "(layer: " + self.name + ")."
#    2507         )
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:2345, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2341     return tf.nest.map_structure(
#    2342         keras_tensor.KerasTensor, output_signature
#    2343     )
#    2344 else:
# -> 2345     return self._infer_output_signature(
#    2346         inputs, args, kwargs, input_masks
#    2347     )
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:2404, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2402         self._maybe_build(inputs)
#    2403         inputs = self._maybe_cast_inputs(inputs)
# -> 2404         outputs = call_fn(inputs, *args, **kwargs)
#    2406     self._handle_activity_regularization(inputs, outputs)
#    2407 self._set_mask_metadata(
#    2408     inputs, outputs, input_masks, build_graph=False
#    2409 )
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\lstm.py:751, in LSTM.call(self, inputs, mask, training, initial_state)
#     737                 (
#     738                     last_output,
#     739                     outputs,
#    (...)
#     742                     runtime,
#     743                 ) = standard_lstm(**normal_lstm_kwargs)
#     744         else:
#     745             (
#     746                 last_output,
#     747                 outputs,
#     748                 new_h,
#     749                 new_c,
#     750                 runtime,
# --> 751             ) = lstm_with_backend_selection(**normal_lstm_kwargs)
#     753     states = [new_h, new_c]
#     755 if self.stateful:
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\lstm.py:1356, in lstm_with_backend_selection(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1351     # Call the normal LSTM impl and register the cuDNN impl function. The
#    1352     # grappler will kick in during session execution to optimize the graph.
#    1353     last_output, outputs, new_h, new_c, runtime = defun_standard_lstm(
#    1354         **params
#    1355     )
# -> 1356     gru_lstm_utils.function_register(defun_gpu_lstm, **params)
#    1358 return last_output, outputs, new_h, new_c, runtime
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\gru_lstm_utils.py:257, in function_register(func, *args, **kwargs)
#     238 def function_register(func, *args, **kwargs):
#     239     """Register a specialization of a `Function` into the graph.
#     240
#     241     This won't actually call the function with the inputs, and only put the
#    (...)
#     255         function.
#     256     """
# --> 257     concrete_func = func.get_concrete_function(*args, **kwargs)
#     258     concrete_func.add_to_graph()
#     259     concrete_func.add_gradient_functions_to_graph()
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2610, in Function.get_concrete_function(self, *args, **kwargs)
#    2601 def get_concrete_function(self, *args, **kwargs):
#    2602   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    2603
#    2604   Args:
#    (...)
#    2608        or `tf.Tensor` or `tf.TensorSpec`.
#    2609   """
# -> 2610   graph_function = self._get_concrete_function_garbage_collected(
#    2611       *args, **kwargs)
#    2612   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2613   return graph_function
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2576, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2574   args, kwargs = None, None
#    2575 with self._lock:
# -> 2576   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577   seen_names = set()
#    2578   captured = object_identity.ObjectIdentitySet(
#    2579       graph_function.graph.internal_captures)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1247, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1244 else:
#    1245   _, original_func = tf_decorator.unwrap(python_func)
# -> 1247 func_outputs = python_func(*func_args, **func_kwargs)
#    1249 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1250 # TensorArrays and `None`s.
#    1251 func_outputs = nest.map_structure(
#    1252     convert, func_outputs, expand_composites=True)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\lstm.py:1260, in lstm_with_backend_selection.<locals>.gpu_lstm_with_fallback(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask, return_sequences)
#    1258 """Use cuDNN kernel when mask is none or strictly right padded."""
#    1259 if mask is None:
# -> 1260     return gpu_lstm(
#    1261         inputs=inputs,
#    1262         init_h=init_h,
#    1263         init_c=init_c,
#    1264         kernel=kernel,
#    1265         recurrent_kernel=recurrent_kernel,
#    1266         bias=bias,
#    1267         mask=mask,
#    1268         time_major=time_major,
#    1269         go_backwards=go_backwards,
#    1270         sequence_lengths=sequence_lengths,
#    1271         return_sequences=return_sequences,
#    1272     )
#    1274 def cudnn_lstm_fn():
#    1275     return gpu_lstm(
#    1276         inputs=inputs,
#    1277         init_h=init_h,
#    (...)
#    1286         return_sequences=return_sequences,
#    1287     )
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\layers\rnn\lstm.py:1149, in gpu_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, mask, time_major, go_backwards, sequence_lengths, return_sequences)
#    1139         inputs = tf.reverse(inputs, axis=[0])
#    1140     outputs, h, c, _ = tf.raw_ops.CudnnRNN(
#    1141         input=inputs,
#    1142         input_h=init_h,
#    (...)
#    1146         rnn_mode="lstm",
#    1147     )
# -> 1149 last_output = outputs[-1]
#    1150 if not time_major and sequence_lengths is None and return_sequences:
#    1151     outputs = tf.transpose(outputs, perm=[1, 0, 2])
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:1071, in _slice_helper(tensor, slice_spec, var)
#    1066 with ops.name_scope(
#    1067     None,
#    1068     "strided_slice", [tensor] + begin + end + strides,
#    1069     skip_on_eager=False) as name:
#    1070   if begin:
# -> 1071     packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
#    1072                                                 stack(strides))
#    1073     # TODO(mdan): Instead of implicitly casting, it's better to enforce the
#    1074     # same dtypes.
#    1075     if (packed_begin.dtype == dtypes.int64 or
#    1076         packed_end.dtype == dtypes.int64 or
#    1077         packed_strides.dtype == dtypes.int64):
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\array_ops.py:1468, in stack(values, axis, name)
#    1465 if axis == 0:
#    1466   try:
#    1467     # If the input is a constant list, it can be converted to a constant op
# -> 1468     return ops.convert_to_tensor(values, name=name)
#    1469   except (TypeError, ValueError, NotImplementedError):
#    1470     pass  # Input list contains non-constant tensors
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:343, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     340 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:735, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     733   inp = self.capture(inp)
#     734   captured_inputs.append(inp)
# --> 735 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     736     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     737     compute_device)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:3800, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3797 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3798 # Session.run call cannot occur between creating and mutating the op.
#    3799 with self._mutation_lock():
# -> 3800   ret = Operation(
#    3801       node_def,
#    3802       self,
#    3803       inputs=inputs,
#    3804       output_types=dtypes,
#    3805       control_inputs=control_inputs,
#    3806       input_types=input_types,
#    3807       original_op=self._default_original_op,
#    3808       op_def=op_def)
#    3809   self._create_op_helper(ret, compute_device=compute_device)
#    3810 return ret
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:2108, in Operation.__init__(***failed resolving arguments***)
#    2105     control_input_ops.append(control_op)
#    2107 # Initialize c_op from node_def and other inputs
# -> 2108 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2109 self._init_from_c_op(c_op=c_op, g=g)
#    2111 self._original_op = original_op
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\clickratio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:1966, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1962   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1963                                          serialized)
#    1965 try:
# -> 1966   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1967 except errors.InvalidArgumentError as e:
#    1968   # Convert to ValueError for backwards compatibility.
#    1969   raise ValueError(e.message)
#
# KeyboardInterrupt:
